# %% [markdown]
# Vamos a definir una funcion que nos permita leer los archivos de cada clase de metricas para cada municipio, y exportar el nuevo dataframe a un nuevo csv.

# %%
import pandas as pd
import os
import glob
import os
import string

# %% [markdown]
# # Funcion para leer los nombres de los archivos txt. La funcion tiene como argumento la ruta del directorio donde se encuentran los archivos

# %%
def leer_archivos(path):
    os.chdir(path)
    file_name = []
    for file in os.listdir():
        file_name.append(file)
    return (file_name)

# %%
ruta_forma = (r"C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\forma")
archivos_forma = leer_archivos(ruta_forma)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\funcion_leer_metricas.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> ruta_forma = (r"C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\forma")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> archivos_forma = leer_archivos(ruta_forma)
#
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\funcion_leer_metricas.ipynb Cell 5 in 2
# ...

# %%
archivos_forma = leer_archivos(ruta_forma)

# %%
archivos_forma
# Out:
# ['Albacete.txt',
#  'Alcala.txt',
#  'Alconbendas.txt',
#  'Alcorcon.txt',
#  'Algeciras.txt',
#  'Alicante.txt',
#  'Almeria.txt',
#  'Avila.txt',
#  'Badajoz.txt',
#  'Badalona.txt',
#  'Barcelona.txt',
#  'Burgos.txt',
#  'Caceres.txt',
#  'Cadiz.txt',
#  'Cartagena.txt',
#  'Castello.txt',
#  'Ceuta.txt',
#  'Ciudad Real.txt',
#  'Cordoba.txt',
#  'Corunia.txt',
#  'Cuenca.txt',
#  'DosHermanas.txt',
#  'Elche.txt',
#  'Fuentelabra.txt',
#  'Getafe.txt',
#  'Gijon.txt',
#  'Girona.txt',
#  'Granada.txt',
#  'Guadalajara.txt',
#  'Hospitalet.txt',
#  'Huelva.txt',
#  'Huesca.txt',
#  'Jaen.txt',
#  'Jerez.txt',
#  'Las Palmas.txt',
#  'Leganes.txt',
#  'Leon.txt',
#  'LLeida.txt',
#  'LogroÃ±o.txt',
#  'Lugo.txt',
#  'Madrid.txt',
#  'Malaga.txt',
#  'Marbella.txt',
#  'Mataro.txt',
#  'Melilla.txt',
#  'Mostoles.txt',
#  'Murcia.txt',
#  'Ourense.txt',
#  'Oviedo.txt',
#  'Palencia.txt',
#  'Palma.txt',
#  'Parla.txt',
#  'Pontevedra.txt',
#  'Sabadell.txt',
#  'Salamanca.txt',
# ...

# %% [markdown]
# ### La siguiente funcion lee las métricas de forma cada documento y las junta en un nuevo dataframe.
# ### Los argumentos son:
#
#  1.- Files: Un diccionario con el nombre de los archivos.
#
#  2.- n = El número de lineas desde la parte final del documento donde se encuentran las metricas.
#
#  3.- metricas = El nombre de las métricas que forman las columnas del nuevo dataset.

# %%
def crear_df_metricas(files,n, metricas):
    dict_metricas = {}
    df_metricas = pd.DataFrame(columns= metricas)
    for file in files:
        n = n
        with open(file) as f:
            lines = f.readlines()[n:]
            for line in lines:
                x = line.split(" ", 1)
                dict_metricas[x[0]] = x[1][:-1]                 
                df_temp = pd.DataFrame(dict_metricas, index = [file])
            df_metricas = pd.concat([df_metricas,df_temp], axis = 0)   
    
    return df_metricas

# %%
metricas_forma = ['PAFRAC', 'SHAPE_MN', 'SHAPE_MD', 'PARA_MN', 'PARA_MD', 'FRAC_MN', 'FRAC_MD', 'SQUARE_MN', 'SQUARE_MD']

# %%
ciudades_forma = crear_df_metricas(archivos_forma,-9,metricas_forma)

# %%
ciudades_forma
# Out:
#                    PAFRAC  SHAPE_MN  SHAPE_MD   PARA_MN   PARA_MD   FRAC_MN
# Albacete.txt     1.036782  1.239875  1.196013  0.251356  0.242674  1.071821  \
# Alcala.txt       1.025171  1.293679  1.267219  0.325155  0.328765  1.095561
# Alconbendas.txt  1.028039  1.247419  1.185695  0.205145  0.164615  1.066683
# Alcorcon.txt     1.029029  1.248374  1.223028  0.262249  0.250720  1.068275
# Algeciras.txt    1.048912  1.259996  1.214451  0.404055  0.386923  1.091095
# ...                   ...       ...       ...       ...       ...       ...
# Valencia.txt     1.042692  1.257228  1.213188  0.306693  0.276416  1.079785
# Valladolid.txt   1.029885  1.260936  1.224576  0.297016  0.258540  2.406995
# Vigo.txt         1.109125  1.296248  1.232625  0.278694  0.239418  1.086155
# Zamora.txt       1.047176  1.260158  1.217223  0.350769  0.330062  1.086805
# Zaragoza.txt     1.045270  1.245742  1.197868  0.269641  0.255703  1.074214
#
#                   FRAC_MD  SQUARE_MN SQUARE_MD Landscape
# ...

# %%
ciudades_forma_drop = ciudades_forma.drop("Landscape", axis = 1)

# %%
ciudades_forma_drop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\funcion_leer_metricas.ipynb Cell 14 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> ciudades_forma_drop
#
# NameError: name 'ciudades_forma_drop' is not defined

# %%
#ciudades_forma_drop.to_csv(r"C:/projectos/manifolds/ciudades/datos/metricas/metricas_forma.csv")

# %%
ciudades_forma_drop.to_csv(r"C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_forma.csv", encoding='ISO-8859-1')

# %% [markdown]
# # Diversidad

# %%
# Metricas diversidad

# n = 11
metricas_diversidad = ['PR','PRD','SHDI','SIDI','MSIDI','SHEI','SIEI','MSIEI','IEI']

# %%
#ruta_diversidad = (r"C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\diversidad")
ruta_diversidad = (r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\diversidad")

archivos_diversidad = leer_archivos(ruta_diversidad)

# %%
ciudades_diversidad = crear_df_metricas(archivos_diversidad,-9,metricas_diversidad)

# %%
ciudades_diversidad
# Out:
#                PR       PRD      SHDI      SIDI     MSIDI      SHEI      SIEI  \
# Albacete.txt    8  0.498351  0.723601  0.755052  1.406710  0.745706  0.862917
# Alcala.txt      8  0.495263  0.769670  0.746116  1.370878  0.771443  0.852704
# Alcobendas.txt  8  0.495263  0.769670  0.746116  1.370878  0.771443  0.852704
# Alcorcon.txt    8  1.016461  0.714969  0.757634  1.417307  0.751111  0.865868
# Algeciras.txt   8  0.752361  1.209382  0.625019  0.980880  0.626374  0.714308
# ...            ..       ...       ...       ...       ...       ...       ...
# Valencia.txt    8  0.369649  0.871006  0.710258  1.238763  0.723575  0.811723
# Valladolid.txt  8  0.289363  0.708775  0.762939  1.439438  0.757313  0.871930
# Vigo.txt        8  0.299214  0.924350  0.691404  1.175722  0.674770  0.790176
# Zamora.txt      8  1.449856  0.673657  0.774217  1.488181  0.758289  0.884820
# Zaragoza.txt    8  0.190993  0.765839  0.742138  1.355330  0.731288  0.848158
#
# ...

# %%
ciudades_diversidad = ciudades_diversidad.iloc[:,0:9]
ciudades_diversidad
# Out:
#                PR       PRD      SHDI      SIDI     MSIDI      SHEI      SIEI  \
# Albacete.txt    8  0.498351  0.723601  0.755052  1.406710  0.745706  0.862917
# Alcala.txt      8  0.495263  0.769670  0.746116  1.370878  0.771443  0.852704
# Alcobendas.txt  8  0.495263  0.769670  0.746116  1.370878  0.771443  0.852704
# Alcorcon.txt    8  1.016461  0.714969  0.757634  1.417307  0.751111  0.865868
# Algeciras.txt   8  0.752361  1.209382  0.625019  0.980880  0.626374  0.714308
# ...            ..       ...       ...       ...       ...       ...       ...
# Valencia.txt    8  0.369649  0.871006  0.710258  1.238763  0.723575  0.811723
# Valladolid.txt  8  0.289363  0.708775  0.762939  1.439438  0.757313  0.871930
# Vigo.txt        8  0.299214  0.924350  0.691404  1.175722  0.674770  0.790176
# Zamora.txt      8  1.449856  0.673657  0.774217  1.488181  0.758289  0.884820
# Zaragoza.txt    8  0.190993  0.765839  0.742138  1.355330  0.731288  0.848158
#
# ...

# %%
ciudades_diversidad.to_csv(r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_diversidad.csv",
 encoding='ISO-8859-1')

# %% [markdown]
# # AREA

# %%
#ruta_area = (r"C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\area")
ruta_area = (r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\area")
archivos_area = leer_archivos(ruta_area)

# %%
## Metricas area

#n_area = -10
metricas_area  = ["TA","LPI","AREA_MN","AREA_AM","AREA_MD","GYRATE_MN","GYRATE_AM","GYRATE_MD"]

# %%
ciudades_area = crear_df_metricas(archivos_area,-9,metricas_area)
ciudades_area
# Out:
#                          TA       LPI   AREA_MN   AREA_AM   AREA_MD  \
# Albacete.txt    1605.293355  2.929497  0.116461  2.976411  0.031520
# Alcala.txt      1615.304126  2.451039  0.136451  4.559123  0.019854
# Alcobendas.txt  1386.626321  2.882984  0.289423  3.843857  0.069676
# Alcorcon.txt     787.044792  3.295528  0.161214  3.023467  0.028205
# Algeciras.txt   1063.319019  2.044908  0.063300  2.629819  0.013341
# ...                     ...       ...       ...       ...       ...
# Valencia.txt    2164.215491  2.515410  0.065111  4.506163  0.024895
# Valladolid.txt  2764.692882  2.285334  0.170702  9.992102  0.028855
# Vigo.txt        2673.672921  4.253406  0.076896  7.653004  0.037150
# Zamora.txt       551.778808  9.977708  0.075195  6.638329  0.018018
# Zaragoza.txt    4188.643450  1.576180  0.148265  6.420273  0.028926
#
#                 GYRATE_MN  GYRATE_AM GYRATE_MD Landscape    PAFRAC  SHAPE_MN  \
# ...

# %%
ciudades_area = ciudades_area.iloc[:,0:8]

# %%
ciudades_area.to_csv(r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_area.csv")

# %%
# Metricas division

n = 6

metricas_division = ["NP","DIVISION","SPLIT","MESH"]

# %%
ruta_division = (r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\division")
archivos_division = leer_archivos(ruta_division)

# %%
archivos_division
# Out:
# ['Albacete.txt',
#  'Alcala.txt',
#  'Alcobendas.txt',
#  'Alcorcon.txt',
#  'Algeciras.txt',
#  'Alicante.txt',
#  'Almeria.txt',
#  'Avila.txt',
#  'Badalona.txt',
#  'Barcelona.txt',
#  'Bodajoz.txt',
#  'Burgos.txt',
#  'Caceres.txt',
#  'Cadiz.txt',
#  'Cartagena.txt',
#  'Castello.txt',
#  'ceuta.txt',
#  'Ciudad_real.txt',
#  'Cordoba.txt',
#  'Corunia.txt',
#  'Cuenca.txt',
#  'dos_hermanas.txt',
#  'Elche.txt',
#  'FuenteLabra.txt',
#  'Getafe.txt',
#  'Gijon.txt',
#  'Girona.txt',
#  'Granada.txt',
#  'Guadalajara.txt',
#  'Hospitalet.txt',
#  'Huelva.txt',
#  'Huesca.txt',
#  'Jaen.txt',
#  'Jerez.txt',
#  'Las_Palmas.txt',
#  'Leganes.txt',
#  'Leon.txt',
#  'LLeida.txt',
#  'Logronio.txt',
#  'Lugo.txt',
#  'Madrid.txt',
#  'Malaga.txt',
#  'Marbella.txt',
#  'Mataro.txt',
#  'Melilla.txt',
#  'Mostoles.txt',
#  'Murcia.txt',
#  'Ourense.txt',
#  'Oviedo.txt',
#  'Palencia.txt',
#  'Palma.txt',
#  'Parla.txt',
#  'Pontevedra.txt',
#  'Sabadell.txt',
#  'Salamanca.txt',
# ...

# %%
ciudades_division = crear_df_metricas(archivos_division,-4,metricas_division)

# %%
ciudades_division.to_csv(r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_division.csv")

# %%
# Metricas IJI

n = 3

metricas_iji = ["IJI"]

# %%
ruta_iji = (r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\Iji")

# %%
archivos_iji = leer_archivos(ruta_iji)

# %%
ciudades_iji = crear_df_metricas(archivos_iji,-1,metricas_iji)

# %%
ciudades_iji.to_csv(r"C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_iji.csv")

# %%
# Out:
#                       IJI
# Albacete.txt     9.879637
# Alcala.txt      11.528130
# Alcobendas.txt  15.371893
# Alcorcon.txt     8.229806
# Algeciras.txt   10.820873
# ...                   ...
# Valencia.txt    14.618656
# Valladolid.txt  10.983938
# Vigo.txt        11.377132
# Zamora.txt      12.125267
# Zaragoza.txt    12.752300
#
# [72 rows x 1 columns]

# %% [markdown]
# ## A partir de los dataframe de cada tipo vamos a unificarlos

# %%
import pandas as pd
import re
import os

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas

# %%
pd.set_option('display.max_rows', 100)

# %%
ciudades_area = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_area.csv')
ciudades_diversidad = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_diversidad.csv')
ciudades_division = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_division.csv')
ciudades_forma = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_forma.csv')
ciudades_iji = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_iji.csv')

# %%
#ciudades_area = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_area.csv')
#ciudades_diversidad = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_diversidad.csv')
#ciudades_division = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_division.csv')
#ciudades_forma = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_forma.csv')
#ciudades_iji = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\ciudades_iji.csv')

# %%
### Seria necesario homologar todos los nombres de la columna ciudades de igual forma que hicimos. 
### Al igual que hicimos con los nombres de las ciudades de los municipios. 
### De esta forma tambien podriamos homologar a los nombres en las datos socioeconomicos

# %%
def cleaning(df):
    df = df.rename(columns={'Unnamed: 0':'Ciudades'})
    df['Ciudades'] = df['Ciudades'].str.replace(r'\.txt$', '', regex=True )
    df['Ciudades'] = df['Ciudades'].str.replace('_', ' ', regex=True)
    df['Ciudades'] = df['Ciudades'].apply(lambda x: x.title())
    return df

# %%
area_cleaning = cleaning(ciudades_area)

# %%
area_cleaning
# Out:
#          Ciudades           TA        LPI   AREA_MN     AREA_AM   AREA_MD  \
# 0        Albacete  1605.293355   2.929497  0.116461    2.976411  0.031520
# 1          Alcala  1615.304126   2.451039  0.136451    4.559123  0.019854
# 2      Alcobendas  1386.626321   2.882984  0.289423    3.843857  0.069676
# 3        Alcorcon   787.044792   3.295528  0.161214    3.023467  0.028205
# 4       Algeciras  1063.319019   2.044908  0.063300    2.629819  0.013341
# 5        Alicante  2644.252980   1.662929  0.133360    2.778957  0.026882
# 6         Almeria  1221.025597   2.647566  0.047095    3.179176  0.011569
# 7           Avila  1221.025597   2.647566  0.047095    3.179176  0.011569
# 8         Badagoz  2459.102190   2.496544  0.117638    3.880530  0.017477
# 9        Badalona   681.177151   4.079243  0.045908    2.010601  0.014343
# 10      Barcelona  4436.370992   1.165791  0.063782    4.135431  0.024406
# 11         Burgos  1736.579705   2.081176  0.185730    5.610663  0.030097
# ...

# %%
diversidad_cleaning = cleaning(ciudades_diversidad)

# %%
diversidad_cleaning
# Out:
#          Ciudades  PR       PRD      SHDI      SIDI     MSIDI      SHEI  \
# 0        Albacete   8  0.498351  0.723601  0.755052  1.406710  0.745706
# 1          Alcala   8  0.495263  0.769670  0.746116  1.370878  0.771443
# 2      Alcobendas   8  0.495263  0.769670  0.746116  1.370878  0.771443
# 3        Alcorcon   8  1.016461  0.714969  0.757634  1.417307  0.751111
# 4       Algeciras   8  0.752361  1.209382  0.625019  0.980880  0.626374
# 5        Alicante   8  0.302543  0.758450  0.742545  1.356912  0.741693
# 6         Almeria   8  0.655187  0.713636  0.759126  1.423480  0.762750
# 7           Avila   8  1.096773  0.664081  0.780506  1.516428  0.780474
# 8         Badajoz   8  0.325322  1.675347  0.541120  0.778966  0.551175
# 9        Badalona   8  1.174438  0.667509  0.779475  1.511744  0.777582
# 10      Barcelona   8  0.180328  0.830052  0.726807  1.297576  0.761850
# 11         Burgos   8  0.460676  1.032058  0.668666  1.104628  0.667596
# ...

# %%
division_cleaning = cleaning(ciudades_division)

# %%
division_cleaning
# Out:
#                Ciudades      NP  DIVISION        SPLIT          MESH
# 0              Albacete   13784  0.998146   539.338537  2.976411e+04
# 1                Alcala   11838  0.997178   354.301500  4.559123e+04
# 2            Alcobendas    4791  0.997228   360.738228  3.843857e+04
# 3              Alcorcon    4882  0.996158   260.312025  3.023467e+04
# 4             Algeciras   16798  0.997527   404.331644  2.629819e+04
# 5              Alicante   19828  0.998949   951.527179  2.778957e+04
# 6               Almeria   25927  0.997396   384.069792  3.179176e+04
# 7                 Avila    7089  0.991158   113.102202  6.449148e+04
# 8              Badalona   14838  0.997048   338.792854  2.010601e+04
# 9             Barcelona   69555  0.999068  1072.771035  4.135431e+04
# 10              Bodajoz   20904  0.998422   633.702638  3.880530e+04
# 11               Burgos    9350  0.996769   309.514149  5.610663e+04
# 12              Caceres   11413  0.984475    64.411039  1.559149e+05
# ...

# %%
forma_cleaning = cleaning(ciudades_forma)

# %%
iji_cleaning = cleaning(ciudades_iji)

# %%
# ciudades_area_ren.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\socioeconomicos\csv\ciudades_area_ren.csv',  encoding = "ISO-8859-1")

# %%
# ciudades_area_ren_clean.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\socioeconomicos\csv\ciudades_area_ren_clean.csv',  encoding = "ISO-8859-1")

# %% [markdown]
# ## Necesito ahora un csv con los nombres oficiales de cada ciudad. Sin embargo, antes debo revisar que los nombres de las ciudades cumplan con un minimo de que pueden asociarse los nombres. Para esto creamos una procedimiento que ajusta los nombres

# %%
rep_area = {'Alconbendas':'Alcobendas','Avila':'Ávila','Alicante':'Alicante/Alacant','Alcorcon':'Alcorcón', 'Almeria':'Almería','Alcala':'Alcalá de Henares', 'Cadiz':'Cádiz','Caceres':'Cáceres', 'Cordoba':'Córdoba', 'Castellon':'Castelló de la Plana', 'Castello': 'Castelló de la Plana', 'Castella':'Castelló de la Plana','Ciudad real':'Ciudad Real', 'Ciudadreal':'Ciudad Real','Bodajoz':'Badajoz','Badagoz':'Badajoz', 'DosHermanas':'Dos Hermanas', 'Doshermanas':'Dos Hermanas','Fuentelabra':'Fuenlabrada', 'Fuenlabradada':'Fuenlabrada',
'Leganes':'Leganés', 'Laganes':'Leganés', 'Logronio':'Logroño','Mataro':'Mataró','Mostoles':'Móstoles','Santacoloma':'Santa Coloma de Gramenet', 'Santacoloma':'Santa Coloma de Gramenet', 'Santacruz':'Santa Cruz de Tenerife', 'Jaen':'Jaén','Jerez':'Jerez de la Frontera','Leon':'León','Malaga':'Málaga',
'San cristobal':'San Cristóbal de La Laguna', 'San Cristobal':'San Cristóbal de La Laguna','Terrasa':'Terrassa','Terragona':'Tarragona','Torrejon':'Torrejón de Ardoz','Corunia':'Coruña, A','Gijon':'Gijón',
'Mallorca':'Palma de Mallorca','Palmas': 'Palmas de Gran Canaria, Las', 'Elche': 'Elche/Elx', 'Hospitalet':"Hospitalet de Llobregat, L'"}

# %%
rep_diversidad = {'Alconbendas':'Alcobendas','Avila':'Ávila','Alicante':'Alicante/Alacant','Alcorcon':'Alcorcón', 'Almeria':'Almería','Alcala':'Alcalá de Henares', 'Cadiz':'Cádiz','Caceres':'Cáceres', 'Cordoba':'Córdoba', 'Castellon':'Castelló de la Plana', 'Castello': 'Castelló de la Plana', 'Castella':'Castelló de la Plana','Ciudad real':'Ciudad Real', 'Ciudadreal':'Ciudad Real','Bodajoz':'Badajoz','Badagoz':'Badajoz', 'DosHermanas':'Dos Hermanas', 'Doshermanas':'Dos Hermanas','Fuentelabra':'Fuenlabrada', 'Fuenlabradada':'Fuenlabrada',
'Leganes':'Leganés', 'Laganes':'Leganés', 'Logronio':'Logroño','Mataro':'Mataró','Mostoles':'Móstoles','Santacoloma':'Santa Coloma de Gramenet', 'Santa Coloma':'Santa Coloma de Gramenet', 'SantaColoma':'Santa Coloma de Gramenet', 'Santacruz':'Santa Cruz de Tenerife', 'Santa Cruz Tenerife':'Santa Cruz de Tenerife', 'Santa Cruz':'Santa Cruz de Tenerife','Jaen':'Jaén','Jerez':'Jerez de la Frontera','Leon':'León','Malaga':'Málaga',
'San cristobal':'San Cristóbal de La Laguna', 'San Cristobal':'San Cristóbal de La Laguna','Terrasa':'Terrassa','Terragona':'Tarragona','Torrejon':'Torrejón de Ardoz','Corunia':'Coruña, A','Gijon':'Gijón',
'Mallorca':'Palma de Mallorca','Palmas':'Palmas de Gran Canaria, Las', 'Elche': 'Elche/Elx', 'Hospitalet':"Hospitalet de Llobregat, L'"}

# %%
rep = {'Alconbendas':'Alcobendas','Avila':'Ávila','Alicante':'Alicante/Alacant','Alcorcon':'Alcorcón', 'Almeria':'Almería','Alcala':'Alcalá de Henares', 'Cadiz':'Cádiz','Caceres':'Cáceres', 'Cordoba':'Córdoba', 'Castellon':'Castelló de la Plana', 'Castello': 'Castelló de la Plana', 'Castella':'Castelló de la Plana','Ciudad real':'Ciudad Real', 'Ciudadreal':'Ciudad Real','Bodajoz':'Badajoz','Badagoz':'Badajoz', 'DosHermanas':'Dos Hermanas', 'Doshermanas':'Dos Hermanas','Fuentelabra':'Fuenlabrada', 'Fuenlabradada':'Fuenlabrada',
'Leganes':'Leganés', 'Laganes':'Leganés', 'Logronio':'Logroño','Mataro':'Mataró','Mostoles':'Móstoles','Santacoloma':'Santa Coloma de Gramenet', 'Santa Coloma':'Santa Coloma de Gramenet', 'SantaColoma':'Santa Coloma de Gramenet', 'Santacruz':'Santa Cruz de Tenerife', 'Santa Cruz Tenerife':'Santa Cruz de Tenerife', 'Santa Cruz':'Santa Cruz de Tenerife','Jaen':'Jaén','Jerez':'Jerez de la Frontera','Leon':'León','Malaga':'Málaga',
'San cristobal':'San Cristóbal de La Laguna', 'San Cristobal':'San Cristóbal de La Laguna','Terrasa':'Terrassa','Terragona':'Tarragona','Torrejon':'Torrejón de Ardoz','Corunia':'Coruña, A','Gijon':'Gijón',
'Mallorca':'Palma de Mallorca','Palmas':'Palmas de Gran Canaria, Las', 'Elche': 'Elche/Elx', 'Hospitalet':"Hospitalet de Llobregat, L'"}

# %%
rep_division = {'Alconbendas':'Alcobendas','Avila':'Ávila','Alicante':'Alicante/Alacant','Alcorcon':'Alcorcón', 'Almeria':'Almería','Alcala':'Alcalá de Henares', 'Cadiz':'Cádiz','Caceres':'Cáceres', 'Cordoba':'Córdoba', 'Castellon':'Castelló de la Plana', 'Castello': 'Castelló de la Plana', 'Castella':'Castelló de la Plana','Ciudad real':'Ciudad Real', 'Ciudadreal':'Ciudad Real','Bodajoz':'Badajoz','Badagoz':'Badajoz', 'DosHermanas':'Dos Hermanas', 'Doshermanas':'Dos Hermanas','Fuentelabra':'Fuenlabrada', 'Fuenlabradada':'Fuenlabrada',
'Leganes':'Leganés', 'Laganes':'Leganés', 'Logronio':'Logroño','Mataro':'Mataró','Mostoles':'Móstoles','Santacoloma':'Santa Coloma de Gramenet', 'Santa Coloma':'Santa Coloma de Gramenet', 'SantaColoma':'Santa Coloma de Gramenet', 'Santa Cruz Tenerife':'Santa Cruz de Tenerife','Jaen':'Jaén','Jerez':'Jerez de la Frontera','Leon':'León','Malaga':'Málaga',
'San cristobal':'San Cristóbal de La Laguna', 'San Cristobal':'San Cristóbal de La Laguna','Terrasa':'Terrassa','Terragona':'Tarragona','Torrejon':'Torrejón de Ardoz','Corunia':'Coruña, A','Gijon':'Gijón',
'Mallorca':'Palma de Mallorca','Palmas':'Palmas de Gran Canaria, Las', 'Elche': 'Elche/Elx', 'Hospitalet':"Hospitalet de Llobregat, L'"}

# %%
def replace_cities(df, replacements):
    for city, replacement in replacements.items():
        df['Ciudades'] = df['Ciudades'].str.replace(city, replacement)
    return df

# %%
def evaluar_cities(df, replacements):
    for city, replacement in replacements.items():
        df['Ciudades'] = df['Ciudades'].str.replace(city, replacement)
    
    nombre_ciudades = df.Ciudades
    nombre_dic = {}
    saltar =  'municipio sin especificar'
    for ciudad in nombre_ciudades:
        filtro_exacto = df_municipios['Municipio'] == ciudad
        filtro_relativo = df_municipios['Municipio'].str.contains(ciudad, regex=True)
        try:
          valor = df_municipios.loc[filtro_exacto, 'Municipio'].iloc[0]
          nombre_dic[ciudad] = valor
        except IndexError:
            print (f"La {ciudad} No funciono")
    return df

# %%
area_replace = replace_cities(area_cleaning, rep_area)

# %%
area_replace
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
diversidad_replace  = replace_cities(diversidad_cleaning, rep_diversidad)

# %%
diversidad_replace
# Out:
#                        Ciudades  PR       PRD      SHDI      SIDI     MSIDI  \
# 0                      Albacete   8  0.498351  0.723601  0.755052  1.406710
# 1             Alcalá de Henares   8  0.495263  0.769670  0.746116  1.370878
# 2                    Alcobendas   8  0.495263  0.769670  0.746116  1.370878
# 3                      Alcorcón   8  1.016461  0.714969  0.757634  1.417307
# 4                     Algeciras   8  0.752361  1.209382  0.625019  0.980880
# 5              Alicante/Alacant   8  0.302543  0.758450  0.742545  1.356912
# 6                       Almería   8  0.655187  0.713636  0.759126  1.423480
# 7                         Ávila   8  1.096773  0.664081  0.780506  1.516428
# 8                       Badajoz   8  0.325322  1.675347  0.541120  0.778966
# 9                      Badalona   8  1.174438  0.667509  0.779475  1.511744
# 10                    Barcelona   8  0.180328  0.830052  0.726807  1.297576
# ...

# %% [markdown]
# # Merge de prueba con los primeros dos datasets

# %%
area_diversidad = area_replace.merge(diversidad_replace, on = 'Ciudades', how = 'inner')

# %%
area_diversidad
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
division_replace  = replace_cities(division_cleaning, rep_division)

# %%
division_replace
# Out:
#                        Ciudades      NP  DIVISION        SPLIT          MESH
# 0                      Albacete   13784  0.998146   539.338537  2.976411e+04
# 1             Alcalá de Henares   11838  0.997178   354.301500  4.559123e+04
# 2                    Alcobendas    4791  0.997228   360.738228  3.843857e+04
# 3                      Alcorcón    4882  0.996158   260.312025  3.023467e+04
# 4                     Algeciras   16798  0.997527   404.331644  2.629819e+04
# 5              Alicante/Alacant   19828  0.998949   951.527179  2.778957e+04
# 6                       Almería   25927  0.997396   384.069792  3.179176e+04
# 7                         Ávila    7089  0.991158   113.102202  6.449148e+04
# 8                      Badalona   14838  0.997048   338.792854  2.010601e+04
# 9                     Barcelona   69555  0.999068  1072.771035  4.135431e+04
# 10                      Badajoz   20904  0.998422   633.702638  3.880530e+04
# ...

# %%
area_diversidad_division = area_diversidad.merge(division_replace, on = 'Ciudades', how = 'inner')

# %%
area_diversidad_division
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
forma_replace  = replace_cities(forma_cleaning, rep)

# %%
forma_replace
# Out:
#                        Ciudades    PAFRAC  SHAPE_MN  SHAPE_MD   PARA_MN  \
# 0                      Albacete  1.036782  1.239875  1.196013  0.251356
# 1             Alcalá de Henares  1.025171  1.293679  1.267219  0.325155
# 2                    Alcobendas  1.028039  1.247419  1.185695  0.205145
# 3                      Alcorcón  1.029029  1.248374  1.223028  0.262249
# 4                     Algeciras  1.048912  1.259996  1.214451  0.404055
# 5              Alicante/Alacant  1.024859  1.240818  1.204889  0.267953
# 6                       Almería  1.027705  1.267989  1.232491  0.416482
# 7                         Ávila  1.034888  1.255290  1.212400  0.321635
# 8                       Badajoz  1.008527  1.263527  1.219802  0.337390
# 9                      Badalona  1.046864  1.336913  1.302643  0.388141
# 10                    Barcelona  1.053047  1.294586  1.247781  0.314192
# 11                       Burgos  1.041695  1.256064  1.222159  0.285839
# ...

# %%
area_diversidad_division_forma = area_diversidad_division.merge(forma_replace, on = 'Ciudades', how = 'inner')

# %%
area_diversidad_division_forma
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
iji_replace  = replace_cities(iji_cleaning, rep)

# %%
iji_replace
# Out:
#                        Ciudades        IJI
# 0                      Albacete   9.879637
# 1             Alcalá de Henares  11.528130
# 2                    Alcobendas  15.371893
# 3                      Alcorcón   8.229806
# 4                     Algeciras  10.820873
# 5              Alicante/Alacant  10.057429
# 6                       Almería  10.810420
# 7                         Ávila  10.374722
# 8                       Badajoz   9.110097
# 9                      Badalona  14.459889
# 10                    Barcelona  17.034972
# 11                       Burgos   8.134834
# 12                      Cáceres   9.008143
# 13                        Cádiz  10.370918
# 14                    Cartagena  12.057665
# 15         Castelló de la Plana  14.856298
# 16                        Ceuta  10.172125
# 17                  Ciudad Real  11.548152
# 18                      Córdoba   8.638293
# 19                    Coruña, A   9.371166
# 20                       Cuenca   8.716950
# ...

# %%
Ciudades_metricas = area_diversidad_division_forma.merge(iji_replace, on = 'Ciudades', how = 'inner' )

# %%
Ciudades_metricas
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %% [markdown]
# ### Exportamo los datos de las metricas

# %%
Ciudades_metricas.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\ciudades_metricas.csv', encoding = "ISO-8859-1")

# %%
Ciudades_metricas.to_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\metricas\Ciudades_metricas.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# ### funcion revisar ciudades

# %%
# buscar los nombres de ciudades en la columna "municipios"
nombre_dic = {}
saltar =  'municipio sin especificar'
for ciudad in nombre_ciudades:
    filtro_exacto = df_municipios['Municipio'] == ciudad
    filtro_relativo = df_municipios['Municipio'].str.contains(ciudad, regex=True)
    try:
        valor = df_municipios.loc[filtro_exacto, 'Municipio'].iloc[0]
        nombre_dic[ciudad] = valor
    except IndexError:
        print (f"La {ciudad} No funciono")
        #mun = df_municipios.loc[filtro_relativo, 'Municipio'].iloc[0]
        #print(mun)
        # nombre_dic[ciudad] = mun
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\funcion_leer_metricas.ipynb Cell 88 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#Y153sZmlsZQ%3D%3D?line=1'>2</a> nombre_dic = {}
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#Y153sZmlsZQ%3D%3D?line=2'>3</a> saltar =  'municipio sin especificar'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#Y153sZmlsZQ%3D%3D?line=3'>4</a> for ciudad in nombre_ciudades:
# ...

# %% [markdown]
# # A partir de aqui tenemos que integrar los datos socioeconomicos

# %% [markdown]
# # Ahora debemos incorporar los valores de los indicadores socioeconomicos.

# %% [markdown]
# Leemos el csv previamente preparado con todos los datos que hemos procesado. Se llama final todos.

# %%
#datos_socioeconomicos = pd.read_csv(r'C:\Users\CRISTIAN\github\clustering-metrics\datos\socioeconomicos\completos\final_todos.txt',  sep='\t', encoding = 'ISO-8859-1')

# %%
datos_socioeconomicos = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\socioeconomicos\completos\final_todos.txt',  sep='\t', encoding = 'ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\metricas\funcion_leer_metricas.ipynb Cell 94 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/metricas/funcion_leer_metricas.ipynb#Y162sZmlsZQ%3D%3D?line=0'>1</a> datos_socioeconomicos = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\socioeconomicos\completos\final_todos.txt',  sep='\t', encoding = 'ISO-8859-1')
#
# NameError: name 'pd' is not defined

# %%
datos_socioeconomicos.columns
# Out:
# Index(['Ciudades', 'Ciudad_renta', 'Renta neta media por persona 2020',
#        'Ciudad_Coches', 'Población Total', 'Población Hombres',
#        'Población Mujeres', 'Parque Vehiculos Total', 'Ciudad_viviendas',
#        'Total viviendas', 'Total viviendas principales',
#        'Viviendas secundarias', 'Viviendas vacias',
#        'Total viviendas colectivas'],
#       dtype='object')

# %%
datos_socioeconomicos = datos_socioeconomicos.drop(['Ciudades'], axis = 1)

# %%
datos_socioeconomicos
# Out:
#                     Ciudad_renta  Renta neta media por persona 2020  \
# 0                       Albacete                              12529
# 1              Alcalá de Henares                              13243
# 2                     Alcobendas                              18684
# 3                       Alcorcón                              13522
# 4                      Algeciras                              10665
# 5                       Alicante                              11676
# 6                        Almería                              11233
# 7                          Ávila                              13209
# 8                        Badajoz                              11775
# 9                       Badalona                              12537
# 10                     Barcelona                              16750
# 11                        Burgos                              14421
# 12                       Cáceres                              12815
# ...

# %%
datos_socioeconomicos = datos_socioeconomicos.rename(columns={'Ciudad_Coches':'Ciudades'})

# %%
nombre_ciudades = datos_socioeconomicos.Ciudades

# %%
Ciudades_metricas
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
datos_socioeconomicos
# Out:
#                     Ciudad_renta  Renta neta media por persona 2020  \
# 0                       Albacete                              12529
# 1              Alcalá de Henares                              13243
# 2                     Alcobendas                              18684
# 3                       Alcorcón                              13522
# 4                      Algeciras                              10665
# 5                       Alicante                              11676
# 6                        Almería                              11233
# 7                          Ávila                              13209
# 8                        Badajoz                              11775
# 9                       Badalona                              12537
# 10                     Barcelona                              16750
# 11                        Burgos                              14421
# 12                       Cáceres                              12815
# ...

# %%
Ciudades_metricas.merge(datos_socioeconomicos, on = 'Ciudades', how = 'right')
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
Ciudades_metricas.merge(datos_socioeconomicos, on = 'Ciudades', how = 'left')
# Out:
#                        Ciudades           TA        LPI   AREA_MN     AREA_AM  \
# 0                      Albacete  1605.293355   2.929497  0.116461    2.976411
# 1             Alcalá de Henares  1615.304126   2.451039  0.136451    4.559123
# 2                    Alcobendas  1386.626321   2.882984  0.289423    3.843857
# 3                      Alcorcón   787.044792   3.295528  0.161214    3.023467
# 4                     Algeciras  1063.319019   2.044908  0.063300    2.629819
# 5              Alicante/Alacant  2644.252980   1.662929  0.133360    2.778957
# 6                       Almería  1221.025597   2.647566  0.047095    3.179176
# 7                         Ávila  1221.025597   2.647566  0.047095    3.179176
# 8                       Badajoz  2459.102190   2.496544  0.117638    3.880530
# 9                      Badalona   681.177151   4.079243  0.045908    2.010601
# 10                    Barcelona  4436.370992   1.165791  0.063782    4.135431
# ...

# %%
datos_metricas_socioeconomicos = Ciudades_metricas.merge(datos_socioeconomicos, on = 'Ciudades', how = 'inner')

# %%
datos_metricas_socioeconomicos.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_metricas_socioeconomicos.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# ### Ultimo paso es integrar las medidas de porcentae de los usos del suelo

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)

# %%
import pandas as pd

datos_filter_porcentajes = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\porcentaje\datos_filter_ciudades_definitivos.csv', encoding = 'ISO-8859-1')

# %%
datos_filter_porcentaje = datos_filter_porcentajes.rename(columns = {'variable':'Ciudades'})

# %%
def shape_cleaning(df):
    df['Ciudades'] = df['Ciudades'].str.replace(r'\.shp$', '', regex=True )
    df['Ciudades'] = df['Ciudades'].str.replace('_', ' ', regex=True)
    df['Ciudades'] = df['Ciudades'].str.replace('Class', '', regex=True )
    df['Ciudades'] = df['Ciudades'].apply(lambda x: x.title())
    return df

# %%
datos_porcentaje_shape_cl = shape_cleaning(datos_filter_porcentaje)

# %%
datos_porcentaje_shape_cl = shape_cleaning(datos_porcentaje_shape_cl)

# %%
datos_porcentaje_shape_cl
# Out:
#     Unnamed: 0                     Ciudades       COM    ED_SING      EQUIP  \
# 0            0                        Avila  0.473221   7.168615  24.106891
# 1            1                       Madrid  0.786506  13.963934  27.126393
# 2            2                       Malaga  1.864575   5.110217  18.105966
# 3            3                       Murcia  1.037803   7.476055  13.777904
# 4            4                      Sevilla  1.465234  14.482170  21.989881
# 5            0                    Albacete   0.445018   6.865100  12.018658
# 6            1                      Alcala   1.557489  11.259171  19.280883
# 7            2                  Alcobendas   0.779649  10.608648  16.118619
# 8            3                    Alcorcon   1.917222   6.864289  33.295606
# 9            4                    Algeciras  1.155169   2.049921  13.420545
# 10           5                    Alicante   1.158216   3.049093  11.658718
# ...

# %%
rep = {'Alconbendas':'Alcobendas','Avila':'Ávila','Alicante':'Alicante/Alacant','Alcorcon':'Alcorcón', 'Almeria':'Almería','Alcala':'Alcalá de Henares', 'Cadiz':'Cádiz','Caceres':'Cáceres', 'Cordoba':'Córdoba', 'Castello De La Plana':'Castelló de la Plana','Ciudad real':'Ciudad Real', 'Ciudadreal':'Ciudad Real','Bodajoz':'Badajoz','Badagoz':'Badajoz', 'Doshermanas':'Dos Hermanas','Fuentelabra':'Fuenlabrada', 'Fuenlabradada':'Fuenlabrada',
'Leganes':'Leganés', 'Laganes':'Leganés', 'Logronio':'Logroño','Mataro':'Mataró','Mostoles':'Móstoles','Santacoloma':'Santa Coloma de Gramenet', 'Santa Coloma':'Santa Coloma de Gramenet', 'SantaColoma':'Santa Coloma de Gramenet', 'Santa Cruz Tenerife':'Santa Cruz de Tenerife','Jaen':'Jaén','Jerez':'Jerez de la Frontera','Leon':'León','Malaga':'Málaga',
'San Cristobal De La Laguna':'San Cristóbal de La Laguna', 'San Cristobal':'San Cristóbal de La Laguna','Terrasa':'Terrassa','Terragona':'Tarragona','Torrejon':'Torrejón de Ardoz','Corunia':'Coruña, A','Gijon':'Gijón',
'Palma':'Palma de Mallorca','Las Palmas Gran Canaria':'Palmas de Gran Canaria, Las', 'Elche': 'Elche/Elx', 'Hospitalet De Llobregat':"Hospitalet de Llobregat, L'"}

# %%
metricas_socioeconomicos
# Out:
#     Unnamed: 0                     Ciudades           TA        LPI   AREA_MN  \
# 0            0                     Albacete  1605.293355   2.929497  0.116461
# 1            1            Alcalá de Henares  1615.304126   2.451039  0.136451
# 2            2                   Alcobendas  1386.626321   2.882984  0.289423
# 3            3                     Alcorcón   787.044792   3.295528  0.161214
# 4            4                    Algeciras  1063.319019   2.044908  0.063300
# 5            5             Alicante/Alacant  2644.252980   1.662929  0.133360
# 6            6                      Almería  1221.025597   2.647566  0.047095
# 7            7                        Ávila  1221.025597   2.647566  0.047095
# 8            8                      Badajoz  2459.102190   2.496544  0.117638
# 9            9                     Badalona   681.177151   4.079243  0.045908
# 10          10                    Barcelona  4436.370992   1.165791  0.063782
# ...

# %%
def replace_cities(df, replacements):
    for city, replacement in replacements.items():
        df['Ciudades'] = df['Ciudades'].str.replace(city, replacement)
    return df

# %%
replace_cities(datos_porcentaje_shape_cl, rep)
# Out:
#     Unnamed: 0                              Ciudades       COM    ED_SING  \
# 0            0                                 Ávila  0.473221   7.168615
# 1            1                                Madrid  0.786506  13.963934
# 2            2                                Málaga  1.864575   5.110217
# 3            3                                Murcia  1.037803   7.476055
# 4            4                               Sevilla  1.465234  14.482170
# 5            0                             Albacete   0.445018   6.865100
# 6            1                    Alcalá de Henares   1.557489  11.259171
# 7            2                           Alcobendas   0.779649  10.608648
# 8            3                             Alcorcón   1.917222   6.864289
# 9            4                             Algeciras  1.155169   2.049921
# 10           5                     Alicante/Alacant   1.158216   3.049093
# 11           6                              Almería   1.197865   6.426124
# ...

# %%
metricas_socioeconomicos = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_metricas_socioeconomicos.csv', encoding = "ISO-8859-1")

# %%
metricas_socioeconomicos.Ciudades
# Out:
# 0                        Albacete
# 1               Alcalá de Henares
# 2                      Alcobendas
# 3                        Alcorcón
# 4                       Algeciras
# 5                Alicante/Alacant
# 6                         Almería
# 7                           Ávila
# 8                         Badajoz
# 9                        Badalona
# 10                      Barcelona
# 11                         Burgos
# 12                        Cáceres
# 13                          Cádiz
# 14                      Cartagena
# 15           Castelló de la Plana
# 16                          Ceuta
# 17                    Ciudad Real
# 18                        Córdoba
# 19                      Coruña, A
# 20                         Cuenca
# 21                   Dos Hermanas
# 22                      Elche/Elx
# 23                    Fuenlabrada
# 24                         Getafe
# 25                          Gijón
# 26                         Girona
# ...
