# %% [markdown]
# # ESCALAMIENTO Y CENTRADO DE VARIABLES

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %%
#dtypes = {'NP':float, 'RNMDP_2020':float,'PobT':float,'PobH':float,'PobM':float,'Vehiculos':float,
#'T_Viviendas':float,'T_Viv_Prin':float,'T_Viv_Sec':float,'Viv_vacias':float,'T_viv_col':float}

# %%
datos = pd.read_csv(r'C:\Users\crist\Documents\GitHub\manifolds\st_urban_cluster\st_urban_clusters\datos_metricas_socioeconomicos_porcentajes.csv', encoding = "ISO-8859-1"
)

# %%
datos = datos.drop(columns='FRAC_MN') # Lo eliminamos porque hay un infinito

# %%
MinMax =  MinMaxScaler()
Maxabs =  MaxAbsScaler()
Std = StandardScaler()
Rscaler =  RobustScaler()
Normalizer =  Normalizer()
QuantileT = QuantileTransformer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\notebook\escalar_variables.ipynb Cell 6 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/notebook/escalar_variables.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> Std = StandardScaler()
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/notebook/escalar_variables.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> Rscaler =  RobustScaler()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/notebook/escalar_variables.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> Normalizer =  Normalizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/crist/Documents/GitHub/manifolds/ciudades/datos/notebook/escalar_variables.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> QuantileT = QuantileTransformer()
#
# TypeError: 'Normalizer' object is not callable

# %%
datos.iloc[:,1:50]
# Out:
#              TA       LPI   AREA_MN   AREA_AM   AREA_MD  GYRATE_MN  GYRATE_AM  \
# 0   1605.293355  2.929497  0.116461  2.976411  0.031520   8.380829  36.057566
# 1   1615.304126  2.451039  0.136451  4.559123  0.019854   7.591469  55.583827
# 2   1386.626321  2.882984  0.289423  3.843857  0.069676  12.998986  45.886723
# 3    787.044792  3.295528  0.161214  3.023467  0.028205   9.644223  43.879007
# 4   1063.319019  2.044908  0.063300  2.629819  0.013341   5.460983  38.065313
# ..          ...       ...       ...       ...       ...        ...        ...
# 67  2164.215491  2.515410  0.065111  4.506163  0.024895   6.216411  38.408851
# 68  2764.692882  2.285334  0.170702  9.992102  0.028855   8.463257  74.230483
# 69  2673.672921  4.253406  0.076896  7.653004  0.037150   7.448687  40.795189
# 70   551.778808  9.977708  0.075195  6.638329  0.018018   6.080244  52.258509
# 71  4188.643450  1.576180  0.148265  6.420273  0.028926   8.365215  65.532054
#
#     GYRATE_MD       PRD      SHDI  ...  T_Viv_Sec  Viv_vacias       COM  \
# 0    5.710261  0.498351  0.723601  ...       5168       15081  0.445018
# 1    4.874116  0.495263  0.769670  ...       1255        5798  1.557489
# 2    9.320043  0.495263  0.769670  ...        566        1513  0.779649
# 3    6.077800  1.016461  0.714969  ...       1303        3488  1.917222
# 4    3.687046  0.752361  1.209382  ...       4700        6686  1.155169
# ..        ...       ...       ...  ...        ...         ...       ...
# 67   4.992987  0.369649  0.871006  ...      33757       57193  2.379026
# 68   5.392190  0.289363  0.708775  ...      10260       18757  0.554566
# 69   6.359690  0.299214  0.924350  ...      10536       18588  0.428888
# 70   4.223122  1.449856  0.673657  ...       5092        6673  1.117133
# 71   5.374877  0.190993  0.765839  ...      14208       35136  0.759848
#
#       ED_SING      EQUIP        IND      OCIO       OFI    RES_PLU    RES_UNI
# 0    6.865100  12.018658  28.687649  0.698910  0.553468  16.789481  33.941716
# 1   11.259171  19.280883  41.836920  0.823273  1.896484  13.994314   9.351466
# 2   10.608648  16.118619  12.718888  0.426558  4.777437  14.142538  40.427664
# 3    6.864289  33.295606  25.021865  0.369681  0.344602  23.836880   8.349856
# 4    2.049921  13.420545  14.524773  0.864348  0.355067  10.734807  56.895370
# ..        ...        ...        ...       ...       ...        ...        ...
# 67   4.969881  20.811788  15.182360  0.892344  0.835998  46.083622   8.844982
# 68   6.484727  20.232697  35.579456  0.798932  0.459606  19.956694  15.933323
# 69   3.261984  15.139326  20.636726  0.557649  0.404116  11.824315  47.746995
# 70   4.423836  24.288501  27.917586  0.424895  0.199479  21.520892  20.107680
# 71   7.166901  14.004037  39.664112  0.305394  0.273807  23.482259  14.343641
#
# [72 rows x 48 columns]

# %%
Std.fit(datos.iloc[:,1:50])
datos_std = Std.transform(datos.iloc[:,1:50])
df_datos_std = pd.DataFrame(datos_std, columns = datos.iloc[:,1:50].columns)
df_datos_std['Ciudades'] = datos['Ciudades']

# %%
df_datos_std.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_std.csv', encoding =  'ISO-8859-1')

# %%
MinMax.fit(datos.iloc[:,1:50])
datos_MinMax = MinMax.transform(datos.iloc[:,1:50])
df_datos_MinMax = pd.DataFrame(datos_MinMax, columns = datos.iloc[:,1:50].columns)
df_datos_MinMax['Ciudades'] = datos['Ciudades']

# %%
df_datos_MinMax.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_MinMax.csv', encoding =  'ISO-8859-1')

# %%
Rscaler.fit(datos.iloc[:,1:50])
datos_Rscaler = Rscaler.transform(datos.iloc[:,1:50])
df_datos_Rscaler = pd.DataFrame(datos_Rscaler, columns = datos.iloc[:,1:50].columns)
df_datos_Rscaler['Ciudades'] = datos['Ciudades']

# %%
df_datos_Rscaler
df_datos_Rscaler.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_Rscaler.csv', encoding =  'ISO-8859-1')

# %%
Maxabs.fit(datos.iloc[:,1:50])
datos_Maxabs = Maxabs.transform(datos.iloc[:,1:50])
df_datos_Maxabs  = pd.DataFrame(datos_Maxabs, columns = datos.iloc[:,1:50].columns)
df_datos_Maxabs['Ciudades'] = datos['Ciudades']

# %%
df_datos_Maxabs.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_Maxabs.csv', encoding =  'ISO-8859-1')

# %%
Normalizer.fit(datos.iloc[:,1:50])
datos_Normalizer= Normalizer.transform(datos.iloc[:,1:50])
df_datos_Normalizer= pd.DataFrame(datos_Normalizer, columns = datos.iloc[:,1:50].columns)
df_datos_Normalizer['Ciudades'] = datos['Ciudades']

# %%
df_datos_Normalizer.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_Normalizer.csv', encoding =  'ISO-8859-1')

# %%
PTrans = PowerTransformer(method='yeo-johnson', standardize=True)

# %%
PTrans.fit(datos.iloc[:,1:50])
datos_PTrans= PTrans.transform(datos.iloc[:,1:50])
df_datos_PTrans= pd.DataFrame(datos_PTrans, columns = datos.iloc[:,1:50].columns)
df_datos_PTrans['Ciudades'] = datos['Ciudades']

# %%
df_datos_PTrans.to_csv(r'C:\Users\crist\Documents\GitHub\manifolds\ciudades\datos\datos_completos\df_datos_PTrans.csv', encoding =  'ISO-8859-1')

# %%
df_datos_PTrans
# Out:
#           TA       LPI   AREA_MN   AREA_AM   AREA_MD  GYRATE_MN  GYRATE_AM  \
# 0   0.660050 -0.215250  0.684610 -0.215862  0.976199   0.929584  -0.349381
# 1   0.669338 -0.558490  1.037263  0.409724 -0.277272   0.453895   0.839406
# 2   0.439142 -0.245309  2.187655  0.171074  2.453814   2.911929   0.374707
# 3  -0.454723  0.000991  1.375026 -0.191186  0.685323   1.587009   0.252967
# 4   0.028074 -0.923886 -0.785608 -0.414564 -1.332723  -1.198402  -0.171375
# ..       ...       ...       ...       ...       ...        ...        ...
# 67  1.098255 -0.507499 -0.718349  0.393908  0.347296  -0.536696  -0.142762
# 68  1.445274 -0.697879  1.481250  1.292464  0.745886   0.976094   1.392235
# 69  1.398466  0.438050 -0.315416  1.031572  1.379736   0.361445   0.042814
# 70 -1.048606  1.564173 -0.370044  0.876240 -0.543334  -0.648783   0.699411
# 71  2.009935 -1.470469  1.210344  0.838086  0.752393   0.920711   1.173508
#
#     GYRATE_MD       PRD      SHDI  ...  Viv_vacias       COM   ED_SING  \
# 0    0.790270 -0.527670 -0.072240  ...    0.553164 -1.456354  0.245565
# 1    0.002883 -0.536226  0.382295  ...   -0.526182  0.841090  0.905405
# 2    2.891977 -0.536226  0.382295  ...   -2.254461 -0.542674  0.828997
# 3    1.085932  0.559429 -0.170590  ...   -1.149315  1.285414  0.245401
# 4   -1.510807  0.079761  1.946794  ...   -0.357780  0.218566 -1.493899
# ..        ...       ...       ...  ...         ...       ...       ...
# 67   0.126114 -0.914447  1.069925  ...    1.875912  1.748782 -0.210798
# 68   0.511343 -1.191767 -0.244049  ...    0.783514 -1.125120  0.166270
# 69   1.295638 -1.156033  1.313620  ...    0.774069 -1.508296 -0.822344
# 70  -0.755101  1.136388 -0.711024  ...   -0.360062  0.150746 -0.378629
# 71   0.495486 -1.578517  0.348582  ...    1.415447 -0.589415  0.305015
#
#        EQUIP       IND      OCIO       OFI   RES_PLU   RES_UNI  \
# 0  -1.124039  0.578967 -0.052483  0.137178 -0.621876  0.736434
# 1   0.311843  1.592292  0.206789  1.669141 -1.043552 -1.128990
# 2  -0.269980 -1.190440 -0.814867  2.165492 -1.019930  1.081756
# 3   2.411640  0.243872 -1.020672 -0.558018  0.273672 -1.246154
# 4  -0.816789 -0.936614  0.283396 -0.515671 -1.607925  1.836653
# ..       ...       ...       ...       ...       ...       ...
# 67  0.575019 -0.849101  0.333336  0.736973  2.293881 -1.187370
# 68  0.476739  1.140708  0.159411 -0.139768 -0.194576 -0.486300
# 69 -0.462382 -0.201355 -0.408094 -0.329216 -1.408786  1.435524
# 70  1.136127  0.510968 -0.820605 -1.259515  0.000629 -0.152752
# 71 -0.693914  1.440807 -1.279365 -0.871391  0.232999 -0.625850
#
#              Ciudades
# 0            Albacete
# 1   Alcalá de Henares
# 2          Alcobendas
# 3            Alcorcón
# 4           Algeciras
# ..                ...
# 67           Valencia
# 68         Valladolid
# 69               Vigo
# 70             Zamora
# 71           Zaragoza
#
# [72 rows x 49 columns]
