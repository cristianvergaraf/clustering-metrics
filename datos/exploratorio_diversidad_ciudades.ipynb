# %% [markdown]
# # Analisis exploratorio de datos

# %%
import pandas as pd

# %%
diversidad_metricas = pd.read_csv('./metricas/ciudades_diversidad_final.csv')

# %%
diversidad_metricas.shape
# Out:
# (72, 11)

# %%
diversidad_ciudades = diversidad_metricas.loc[:,["index","PR","PRD","SHDI","SIDI","MSIDI","SHEI","SIEI","MSIEI"]]

# %%
diversidad_ciudades.head(5)
# Out:
#             index  PR       PRD      SHDI      SIDI     MSIDI      SHEI  \
# 0    Albacete.txt   8  0.498351  0.723601  0.755052  1.406710  0.745706
# 1      Alcala.txt   8  0.495263  0.769670  0.746116  1.370878  0.771443
# 2  Alcobendas.txt   8  0.495263  0.769670  0.746116  1.370878  0.771443
# 3    Alcorcon.txt   8  1.016461  0.714969  0.757634  1.417307  0.751111
# 4   Algeciras.txt   8  0.752361  1.209382  0.625019  0.980880  0.626374
#
#        SIEI     MSIEI
# 0  0.862917  0.676484
# 1  0.852704  0.659253
# 2  0.852704  0.659253
# 3  0.865868  0.681581
# 4  0.714308  0.471704

# %%
diversidad_ciudades.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# PR      72.0  8.069444  0.255992  8.000000  8.000000  8.000000  8.000000
# PRD     72.0  0.850775  0.584099  0.035194  0.412222  0.739803  1.175061
# SHDI    72.0  1.647930  5.427983  0.616999  0.675263  0.736295  0.848233
# SIDI    72.0  0.709329  0.137177  0.041614  0.709889  0.750790  0.774587
# MSIDI   72.0  1.299853  0.319337  0.042504  1.237493  1.389460  1.489823
# SHEI    72.0  0.708965  0.134236  0.062084  0.691308  0.745773  0.777798
# SIEI    72.0  0.810281  0.157486  0.046815  0.811301  0.858046  0.885242
# MSIEI   72.0  0.624331  0.154947  0.019344  0.595108  0.668189  0.716453
#
#              max
# PR      9.000000
# PRD     2.899194
# SHDI   45.947647
# SIDI    0.802926
# MSIDI   1.624175
# SHEI    0.823623
# SIEI    0.917630
# MSIEI   0.781063

# %%
diversidad_ciudades.dtypes
# Out:
# index     object
# PR         int64
# PRD      float64
# SHDI     float64
# SIDI     float64
# MSIDI    float64
# SHEI     float64
# SIEI     float64
# MSIEI    float64
# dtype: object

# %% [markdown]
# # Analisis de la distribucion de cada variable

# %%
diversidad_ciudades.hist()
# Out:
# array([[<AxesSubplot:title={'center':'PR'}>,
#         <AxesSubplot:title={'center':'PRD'}>,
#         <AxesSubplot:title={'center':'SHDI'}>],
#        [<AxesSubplot:title={'center':'SIDI'}>,
#         <AxesSubplot:title={'center':'MSIDI'}>,
#         <AxesSubplot:title={'center':'SHEI'}>],
#        [<AxesSubplot:title={'center':'SIEI'}>,
#         <AxesSubplot:title={'center':'MSIEI'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
from matplotlib import pyplot as plt

fig = plt.figure(figsize = (15,15))
ax = fig.gca()
g = diversidad_ciudades.hist(ax=ax)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_15516\633735382.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   g = diversidad_ciudades.hist(ax=ax)

# %%
diversidad_ciudades.loc[:,["PR","PRD","SHDI","SIDI","MSIDI","SHEI","SIEI","MSIEI"]].corr().style.background_gradient(cmap = "RdYlGn")
# Out:
# <style type="text/css">
# #T_e1f94_row0_col0, #T_e1f94_row1_col1, #T_e1f94_row2_col2, #T_e1f94_row3_col3, #T_e1f94_row3_col5, #T_e1f94_row3_col6, #T_e1f94_row4_col4, #T_e1f94_row4_col7, #T_e1f94_row5_col3, #T_e1f94_row5_col5, #T_e1f94_row5_col6, #T_e1f94_row6_col3, #T_e1f94_row6_col5, #T_e1f94_row6_col6, #T_e1f94_row7_col4, #T_e1f94_row7_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e1f94_row0_col1, #T_e1f94_row0_col3, #T_e1f94_row0_col4, #T_e1f94_row0_col5, #T_e1f94_row0_col6, #T_e1f94_row0_col7, #T_e1f94_row3_col0, #T_e1f94_row3_col2, #T_e1f94_row6_col0, #T_e1f94_row6_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e1f94_row0_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_e1f94_row1_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_e1f94_row1_col2 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_e1f94_row1_col3, #T_e1f94_row1_col6 {
#   background-color: #daf08d;
#   color: #000000;
# }
# ...

# %% [markdown]
# ## Análisis exploratorio división

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
datos_division = pd.read_csv('./metricas/df_division.csv')

# %%
datos_division
# Out:
#     Unnamed: 0           index     NP  DIVISION  SPLIT     MESH
# 0            0    Albacete.txt  13784      1.00 539.34 29764.11
# 1            1      Alcala.txt  11838      1.00 354.30 45591.23
# 2            2  Alcobendas.txt   4791      1.00 360.74 38438.57
# 3            3    Alcorcon.txt   4882      1.00 260.31 30234.67
# 4            4   Algeciras.txt  16798      1.00 404.33 26298.19
# ..         ...             ...    ...       ...    ...      ...
# 67          67    Valencia.txt  33239      1.00 480.28 45061.63
# 68          68  Valladolid.txt  16196      1.00 276.69 99921.02
# 69          69        Vigo.txt  34770      1.00 349.36 76530.04
# 70          70      Zamora.txt   7338      0.99  83.12 66383.29
# 71          71    Zaragoza.txt  28251      1.00 652.41 64202.73
#
# [72 rows x 6 columns]

# %%
datos_division = datos_division.loc[:,['index','NP','DIVISION','SPLIT','MESH']]

# %%
datos_division.head()
# Out:
#             index     NP  DIVISION  SPLIT     MESH
# 0    Albacete.txt  13784      1.00 539.34 29764.11
# 1      Alcala.txt  11838      1.00 354.30 45591.23
# 2  Alcobendas.txt   4791      1.00 360.74 38438.57
# 3    Alcorcon.txt   4882      1.00 260.31 30234.67
# 4   Algeciras.txt  16798      1.00 404.33 26298.19

# %%
datos_division.describe()
# Out:
#              NP  DIVISION   SPLIT       MESH
# count     72.00     72.00   72.00      72.00
# mean   18031.49      0.99  367.11  197603.73
# std    19166.57      0.05  299.15 1057931.77
# min     3438.00      0.55    2.23   10046.17
# 25%     7735.75      0.99  189.72   25915.20
# 50%    11270.50      1.00  274.05   38621.94
# 75%    20969.75      1.00  434.33   68563.81
# max   131191.00      1.00 1425.58 8984539.67

# %%
datos_division.loc[:,['NP','DIVISION','SPLIT','MESH']].corr().style.background_gradient(cmap = "plasma")
# Out:
# <style type="text/css">
# #T_6c2f3_row0_col0, #T_6c2f3_row1_col1, #T_6c2f3_row2_col2, #T_6c2f3_row3_col3 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_6c2f3_row0_col1 {
#   background-color: #d5546e;
#   color: #f1f1f1;
# }
# #T_6c2f3_row0_col2 {
#   background-color: #b83289;
#   color: #f1f1f1;
# }
# #T_6c2f3_row0_col3 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# #T_6c2f3_row1_col0 {
#   background-color: #3e049c;
#   color: #f1f1f1;
# }
# #T_6c2f3_row1_col2 {
#   background-color: #9613a1;
#   color: #f1f1f1;
# }
# #T_6c2f3_row1_col3, #T_6c2f3_row3_col0, #T_6c2f3_row3_col1, #T_6c2f3_row3_col2 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_6c2f3_row2_col0 {
#   background-color: #99159f;
#   color: #f1f1f1;
# }
# #T_6c2f3_row2_col1 {
#   background-color: #e16462;
#   color: #f1f1f1;
# }
# #T_6c2f3_row2_col3 {
#   background-color: #b42e8d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c2f3">
#   <thead>
#     <tr>
# ...

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
g = datos_division.hist(ax = ax)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_15516\3662937423.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   g = datos_division.hist(ax = ax)

# %% [markdown]
# # Jutamos ambos los datos de division y diversidad en un dataframe usando la columna index usando la funcion pd.merge()

# %%
ciudades_paisaje = diversidad_ciudades.merge(datos_division, on = 'index')

# %%
diversidad_ciudades.shape
# Out:
# (72, 9)

# %%
datos_division.shape
# Out:
# (72, 5)

# %%
ciudades_paisaje.loc[:,['PR', 'PRD', 'SHDI', 'SIDI', 'MSIDI', 'SHEI', 'SIEI', 'MSIEI',
       'NP', 'DIVISION', 'SPLIT', 'MESH']].corr().style.background_gradient(cmap = "plasma")
# Out:
# <style type="text/css">
# #T_06cef_row0_col0, #T_06cef_row1_col1, #T_06cef_row2_col2, #T_06cef_row3_col3, #T_06cef_row3_col5, #T_06cef_row3_col6, #T_06cef_row4_col4, #T_06cef_row4_col7, #T_06cef_row5_col3, #T_06cef_row5_col5, #T_06cef_row5_col6, #T_06cef_row6_col3, #T_06cef_row6_col5, #T_06cef_row6_col6, #T_06cef_row7_col4, #T_06cef_row7_col7, #T_06cef_row8_col8, #T_06cef_row9_col9, #T_06cef_row10_col10, #T_06cef_row11_col11 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_06cef_row0_col1, #T_06cef_row0_col10 {
#   background-color: #6400a7;
#   color: #f1f1f1;
# }
# #T_06cef_row0_col2 {
#   background-color: #f9973f;
#   color: #000000;
# }
# #T_06cef_row0_col3, #T_06cef_row0_col4, #T_06cef_row0_col5, #T_06cef_row0_col6, #T_06cef_row0_col7, #T_06cef_row1_col8, #T_06cef_row1_col10, #T_06cef_row3_col0, #T_06cef_row3_col2, #T_06cef_row6_col0, #T_06cef_row6_col2, #T_06cef_row8_col1, #T_06cef_row9_col11, #T_06cef_row11_col9 {
#   background-color: #0d0887;
# ...

# %%
ciudades_paisaje.to_csv(r"C:/projectos/manifolds/ciudades/datos/metricas/ciudades_paisaje.csv")

# %% [markdown]
# # Incluiremos ahora en el analisis los valores porcentuales de clases agregadas para cada ciudad

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 atipicos_ciudades
#
# NameError: name 'atipicos_ciudades' is not defined
